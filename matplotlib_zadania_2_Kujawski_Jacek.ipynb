# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import pandas as pd
data = pd.read_csv("iris_data.csv")
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Zad.1. Dla zmiennej 'SepalLengthCm' utworz piechart z dodana legenda. Czy wizualizacja ta wyglada dobrze?

# %%
#import matplotlib.pyplot as plt
#import numpy as np
labels = data['Id'].tolist()
SepalLengthCm_values = data['SepalLengthCm'].tolist()
fig1, ax1 = plt.subplots()
ax1.pie(SepalLengthCm_values, labels=labels, shadow=True, startangle=90, pctdistance=0.8)
ax1.axis('equal')
plt.title('Iris data')
plt.legend(loc ="right")
plt.show()

# %% [markdown]
# Zad.2. Dla poniższych danych wykonaj wykres budełkowy dla zmiennych 'Hours' i 'Grade'. Pamiętaj o atrakcyjnej kolorystyce oraz zaznaczeniu linii mediany. Czy występują outliery?

# %%
#cateating data
import pandas as pd
df = pd.DataFrame({'Name': ['John', 'Rad', 'Var', 'Mathew', 'Alina', 'Lee', 'Rogers'],
                   'Salary':[60000,64000,60000,289000,66000,50000,60000],
                   'Hours':[41,40,36,30,35,39,40],
                   'Grade':[50,50,46,95,50,5,57]})
print(df)
# Out:
#      Name  Salary  Hours  Grade
# 0    John   60000     41     50
# 1     Rad   64000     40     50
# 2     Var   60000     36     46
# 3  Mathew  289000     30     95
# 4   Alina   66000     35     50
# 5     Lee   50000     39      5
# 6  Rogers   60000     40     57

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv('company_sales_data.csv')
profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()
plt.plot(monthList, profitList, label = 'Month-wise Profit data of last year')
plt.xlabel('Month number')
plt.ylabel('Profit in dollar')
plt.xticks(monthList)
plt.title('Company profit per month')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

# %% [markdown]
# Zad.3. Zmodyfikuj wykres w taki sposób aby wyglądał nastepująco:
#
# ![Screenshot%202021-10-26%20at%2000.11.35.png](attachment:Screenshot%202021-10-26%20at%2000.11.35.png)

# %%
#import matplotlib.pyplot as plt
#import numpy as np
#import pandas as pd
df = pd.read_csv('company_sales_data.csv')
profitList = df ['total_profit'].tolist() # porownaj bez '.tolist()' !!!
monthList  = df ['month_number'].tolist() # porownaj bez '.tolist()' !!!

plt.plot(monthList, profitList, label = 'Profit data of last year', color='r', marker='o', markerfacecolor='k', linestyle='--', linewidth=3)
      
plt.xlabel('Month Number')
plt.ylabel('Profit in dollar')
plt.legend(loc='lower right')
# plt.legend()  dla porownania bedzie legebda u gory!
plt.title('Company Sales data of last year')
plt.xticks(monthList)
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

# %% [markdown]
# Zad.4. Wyświetlaj liczbę sprzedanych jednostek miesięcznie dla każdego produktu za pomocą wykresów wielowierszowych. (tj. oddzielna fabuła dla każdego produktu ).
#
# Wykres powinien wyglądać tak:
#
# ![Screenshot%202021-10-26%20at%2000.13.07.png](attachment:Screenshot%202021-10-26%20at%2000.13.07.png)

# %%
#import matplotlib.pyplot as plt
#import numpy as np
#import pandas as pd
df = pd.read_csv('company_sales_data.csv')
monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()

plt.plot(monthList, faceCremSalesData,   label = 'Face cream Sales Data', marker='o', linewidth=5)
plt.plot(monthList, faceWashSalesData,   label = 'Face Wash Sales Data',  marker='o', linewidth=5)
plt.plot(monthList, toothPasteSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=5)
plt.plot(monthList, bathingsoapSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=5)
plt.plot(monthList, shampooSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=5)
plt.plot(monthList, moisturizerSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=5)

plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.xticks(monthList)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.title('Sales data')
plt.show()

# %% [markdown]
# Zad.5. Za pomocą subplotów spróbuj wykonać następujące wykresy:
#
# ![Screenshot%202021-10-26%20at%2000.14.12.png](attachment:Screenshot%202021-10-26%20at%2000.14.12.png)

# %%
#import matplotlib.pyplot as plt
#import numpy as np
#import pandas as pd
df = pd.read_csv('company_sales_data.csv')
monthList  = df ['month_number'].tolist()
bathingsoap   = df ['bathingsoap'].tolist()
faceWashSalesData   = df ['facewash'].tolist()

f, axarr = plt.subplots(2, sharex=True) # wazna funkcja: sharex=True    !!!!!!!!!!!!!!!
axarr[0].plot(monthList, bathingsoap, label = 'Bathingsoap Sales Data', color='k', marker='o', linewidth=2)
axarr[0].set_title('Sales data of  a Bathingsoap')
axarr[1].plot(monthList, faceWashSalesData, label = 'Face Wash Sales Data', color='r', marker='o', linewidth=2)
axarr[1].set_title('Sales data of  a facewash')

plt.xticks(monthList)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.show()
