# %% [markdown]
# # Pandas- aplikowanie funkcji na zestawach danych - apply()

# %% [markdown]
# ### importy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### datasety

# %%
mat = pd.read_csv('D:/Dydaktyka/Analiza_Danych_w_Pythonie/adpyr1-materialy-master/zadania/pandas_zadania/student-mat.csv', sep=';')
por = pd.read_csv('D:/Dydaktyka/Analiza_Danych_w_Pythonie/adpyr1-materialy-master/zadania/pandas_zadania/student-por.csv', sep=';')

# %% [markdown]
# Te dane dotyczą osiągnięć uczniów w szkołach średnich dwóch portugalskich szkół. Atrybuty danych obejmują :
# - oceny uczniów,
# - cechy demograficzne, społeczne i związane ze szkołą
#
# <br> i zostały zebrane za pomocą szkolnych raportów i kwestionariuszy.
# <br> Dostarczono dwa zestawy danych dotyczące wyników w dwóch odrębnych przedmiotach: matematyka (mat) i język portugalski (por).

# %% [markdown]
# ### podstawowe informacje o danych

# %%
mat.shape
mat_2 = mat.iloc[:, 0:30]
mat_2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# ### Zad. 1. Z obydwu datasetów odrzuć ostatnie 3 kolumny. Ze względu na to, że nie mamy ich opisu nie mozemy ich zinterpretować.

# %%
por_2 = mat.iloc[:, 0:30]
por_2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# ### Zad. 2. Napisz funkcję, która podniesie do wielkiej litery nazwy kolumn. Zmień je w datasecie mat. (dla chętnych: zrobienie tego za pomocą lambdy)

# %%
mat_2.columns = [columns.capitalize() for columns in mat_2]
list(mat_2.columns) # lista kolumn
# Out:
# ['School',
#  'Sex',
#  'Age',
#  'Address',
#  'Famsize',
#  'Pstatus',
#  'Medu',
#  'Fedu',
#  'Mjob',
#  'Fjob',
#  'Reason',
#  'Guardian',
#  'Traveltime',
#  'Studytime',
#  'Failures',
#  'Schoolsup',
#  'Famsup',
#  'Paid',
#  'Activities',
#  'Nursery',
#  'Higher',
#  'Internet',
#  'Romantic',
#  'Famrel',
#  'Freetime',
#  'Goout',
#  'Dalc',
#  'Walc',
#  'Health',
#  'Absences']

# %% [markdown]
# ### Zad. 3. Spróbuj zaaplikować te funkcję również na na kolumnach Fjob oraz Mjob dla zestawu mat.

# %%
mat_2.Fjob = mat_2['Fjob'].str.capitalize()
mat_2.Mjob = mat_2['Mjob'].str.capitalize()
mat_2
# mat_2.Fjob
# mat_2.Mjob
# Out:
#     School Sex  Age Address Famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  Services  Services
# 391     MS   M   17       U     LE3       T     3     1  Services  Services
# 392     MS   M   21       R     GT3       T     1     1     Other     Other
# 393     MS   M   18       R     LE3       T     3     2  Services     Other
# 394     MS   M   19       U     LE3       T     1     1     Other   At_home
#
# ...

# %% [markdown]
# ### Zad. 4. Napisz funkcje, ktora zwroci True albo False jeśli dany student ma powyżej 16 lat. Nazwij ja jak chcesz.

# %%
def check_age(age):
    if age > 16:
        return ('True')
    else:
        return ('False')

mat_2['Age'].apply(check_age)
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 390     True
# 391     True
# 392     True
# 393     True
# 394     True
# Name: Age, Length: 395, dtype: object

# %% [markdown]
# ### Zad. 5. Uzywajac powyzszej funkcji dodaj do wybranego zestawu danych kolumne z informacja, ktora jest wynikiem funkcji.

# %%
mat_2.check_age = por_2['age'].apply(check_age) # wiaze ze soba MAT i POR
mat_2
# Out:
#     School Sex  Age Address Famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  Services  Services
# 391     MS   M   17       U     LE3       T     3     1  Services  Services
# 392     MS   M   21       R     GT3       T     1     1     Other     Other
# 393     MS   M   18       R     LE3       T     3     2  Services     Other
# 394     MS   M   19       U     LE3       T     1     1     Other   At_home
#
# ...

# %% [markdown]
# ### Zad. 6 ** Zbuduj macierz koleracji dla por. Gdzie widzisz najwieksze zaleznosci i z czego moga one wynikac?

# %%
por.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.107832 -0.121050    0.034490  -0.008415  0.319968
# Medu       -0.107832  1.000000  0.647477   -0.265079   0.097006 -0.172210
# Fedu       -0.121050  0.647477  1.000000   -0.208288   0.050400 -0.165915
# traveltime  0.034490 -0.265079 -0.208288    1.000000  -0.063154  0.097730
# studytime  -0.008415  0.097006  0.050400   -0.063154   1.000000 -0.147441
# failures    0.319968 -0.172210 -0.165915    0.097730  -0.147441  1.000000
# famrel     -0.020559  0.024421  0.020256   -0.009521  -0.004127 -0.062645
# freetime   -0.004910 -0.019686  0.006841    0.000937  -0.068829  0.108995
# goout       0.112805  0.009536  0.027690    0.057454  -0.075442  0.045078
# Dalc        0.134768 -0.007018  0.000061    0.092824  -0.137585  0.105949
# Walc        0.086357 -0.019766  0.038445    0.057007  -0.214925  0.082266
# health     -0.008750  0.004614  0.044910   -0.048261  -0.056433  0.035588
# ...

# %% [markdown]
# ### Zad. 7. Zbuduj funkcje, ktora dla konkretnego Fjob bedzie przypisywala wartosc wynagrodzenia. Wartosci wybierz "na oko", albo bazujac na wlasnej wiedzy. Dodaj kolumne z tymi wartosciami do zestawu por.

# %%
duplikaty_mat_2 = mat_2['Fjob'].drop_duplicates() # sprawdzam, co sie powtarza, by z tego wybrac
duplikaty_mat_2
# Out:
# 0      Teacher
# 1        Other
# 3     Services
# 10      Health
# 32     At_home
# Name: Fjob, dtype: object

# %%
def salary(occupation):
    slownik = {"Teacher": 2400, "Other": 2000, "Services": 3500, "Health": 15000, "At_home": 1000}
    return slownik.get(occupation)

por_2['add_salary'] = mat_2['Fjob'].apply(salary)

por_2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...
